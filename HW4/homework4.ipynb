# %% [markdown]
# #Myungha Kim Homework 4
#
# ##Problem 1
# 1. Speculate on whether you believe that so-called “deep” neural networks are destined to be another bust just as perceptrons and expert systems were in the past, or whether they really are a breakthrough that will be used for years into the future. Please give a two-to-three-paragraph answer, including examples to back up your argument.
#
#
# First to mention the difference between deep neural networks and expert systmes, expert systems require manually created database for rules in text form--which can be tedious process--while neural networks creates their own rules which are represented as weights between points on a grid via training by the input data.
#
# Neural networks has their advantages with dealing with uncertainty and sophisticated pattern recognition. For instance, to answer the questions auch as "what will the weather be like tomorrow?", expert systems would need to go through endless amount of values and writing out rules on how to answer the question which is virtually impossible (expert systems cannot handle time). On the other hand, neural networks will compute the answer as they are a series of stacked regression equations.
#
# However, neural networks have its weakness at explaining for the conclusions they make. Neural networks are called "black box" once they are trained, difficult to interpret what model has learned due to difficulty of understanding the relationship between the representations learned at each layer.
#
# It is hard to say that it will be whether another bust just as perceptrosn and expert systems or a real breakthough for the future at this point. However, as we have seen the pattern of shifting in trends from GOFAI, Bayesian statisitics, machine learning to neural networks, where all those algorithms developed as the complementories for the problems of the past ones, I believe there will be another set of algorithms in the future compensating the problem of neural networks in different perspectives coming up with different answers.
#
#
# Sources
# https://www.quora.com/What-are-the-differences-between-expert-systems-and-artificial-neural-networks
# https://www.quora.com/What-are-the-advantages-disadvantages-of-Artificial-Neural-networks
#
#
#
# ##Problem 3
# 3. Build a Keras-based ConvNet for Keras’s Fashion MNIST dataset (fashion_mnist). Experiment with different network architectures, submit your most performant network, and report the results.

# %%
from keras import layers
from keras import models

model = models.Sequential()

# Configure a convnet with 3 layers of convolutions and max pooling.
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# Add layers to flatten the 2D image and then do a 10-way classification.
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

model.summary()

# load fashion_mnist dataset. 
from keras.datasets import fashion_mnist
from keras.utils import to_categorical

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# print the description of data
print(
    'training image set \
        \n\tcount: {len(train_images)} \
        \n\tshape: {train_images.shape} \
        \n\timage data type: {train_images.dtype} \
        \n\tlabel data type: {train_labels.dtype} \n',
    'testing image set \
        \n\tcount: {len(test_images} \
        \n\tshape: {test_image.shape}\n'
)

train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)



#train and evaluate the model. 
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=5, batch_size=64)
model.evaluate(test_images, test_labels)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_4 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                36928
# ...
